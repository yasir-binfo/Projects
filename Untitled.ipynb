# %% [markdown]
# <a href="https://colab.research.google.com/github/yasir-binfo/Projects/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[4,4,5])
